# %%
class Money:
  def __init__(self):
    self.paise=0
    self.rupees=0
    self.n=0
    self.m=0
  def set_money(self,rupees,paise):
    self.rupees=rupees
    self.paise=paise
  def number(self,n,m):
    self.n=n
    self.m=m
  def add_money(self,moneyrps,moneyps):
    self.rupees=self.rupees+moneyrps
    self.paise=self.paise+moneyps
  def rem_money(self,moneyrps,moneyps):
    self.rupees=self.rupees-self.moneyrps
    self.paise=self.paise-self.moneyps
  def __mul__(self,c):
    temp=Money()
    temp.rupees=self.rupees*c.rupees
    temp.paise=self.paise*c.paise
    return temp
  def __ge__(self,c):
    if self.rupees>=c.rupees:
      return True
    else:
      return False
  def __iadd__(self,c):
    temp=Money()
    self.rupees+=c.rupees
    temp=self.rupees
  def __isub__(self,c):
    temp=c.Money()
    self.rupees-=c.rupees
    temp=self.rupees
  def __truediv__(self,c):
    temp=self.rupees/c.n
    return int(temp)
  def display(self):
    print("Multiplication: ",self.rupees,"rupees",self.paise,"paise")
obj1=Money()
obj1.set_money(2,3)
obj1.add_money(4,5)
obj2=Money()
obj2.set_money(3,4)
obj2.add_money(5,6)
obj3=Money()
obj3=obj1*obj2#mul
obj3.display()
obj4=Money()
obj4.set_money(45,0)
obj5=Money()
obj5.number(5,0)
obj6=Money()
obj6=obj4/obj5
print("The price of 1 item: ",obj6)#div
print(obj1>=obj2)#ge
# Out:
# Multiplication:  48 rupees 80 paise
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-10-b84a09ca51cf> in <module>()
#      54 obj5.set_money(5,0)
#      55 obj6=Money()
# ---> 56 obj6=obj4/obj5
#      57 print("The price of 1 item: ",obj6)#div
#      58 print(obj1>=obj2)#ge
#
# <ipython-input-10-b84a09ca51cf> in __truediv__(self, c)
#      36     temp=self.rupees
#      37   def __truediv__(self,c):
# ---> 38     temp=self.rupees/c.n
#      39     return int(temp)
#      40   def display(self):
#
# ZeroDivisionError: division by zero
