# %%
# Zero Exception
try:
  a=32
  b=0
  print(a/b)
except:
  print("Exception")
# Out:
# Exception

# %%
# Write a program with multiple except blocks and except : handler.(catch all)
x=5
y=0
try:
  print(x/y)
except NameError:
  print("Z is not defined")
except ZeroDivisionError:
  print("You can't divide a number by 0")
except:
  print("Any other Exceptions")
# Out:
# You can't divide a number by 0

# %%
# Write a program in which an exception raised by one function is handled by another function
def func1(x,y):
  try:
    z=x/y
  except:
    func2()
def func2():
  raise ZeroDivisionError("Cannot divide by zero")
func1(10,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-a34804d1abc4> in func1(x, y)
#       3   try:
# ----> 4     z=x/y
#       5   except:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-a34804d1abc4> in <module>()
#       7 def func2():
#       8   raise ZeroDivisionError("Cannot divide by zero")
# ----> 9 func1(10,0)
#
# <ipython-input-6-a34804d1abc4> in func1(x, y)
#       4     z=x/y
#       5   except:
# ----> 6     func2()
#       7 def func2():
#       8   raise ZeroDivisionError("Cannot divide by zero")
#
# <ipython-input-6-a34804d1abc4> in func2()
#       6     func2()
#       7 def func2():
# ----> 8   raise ZeroDivisionError("Cannot divide by zero")
#       9 func1(10,0)
#
# ...

# %%
# Try-except-else
def func(x,y):
  try:
    z=x/y
    print(z)
  except ZeroDivisionError:
    print("warning: Y cannot be 0")
  else:
    print("The answer is: ", z)
func(3,2)
func(5,0)
# Out:
# 1.5
# The answer is:  1.5
# ...

# %%
# Python code to illustrate
# working of try() 
def divide(x, y):
    try:
        # Floor Division : Gives only Fractional
        # Part as Answer
        result = x // y
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")
    else:
        print("Yeah ! Your answer is :", result)
    finally: 
        # this block is always executed  
        # regardless of exception generation. 
        print('This is always executed')
   
# Look at parameters and note the working of Program
divide(3, 2)
divide(3, 0)
# Out:
# Yeah ! Your answer is : 1
# This is always executed
# Sorry ! You are dividing by zero
# This is always executed

# %%
# Try - except - except (catch all) -else -finally
x=[3,55,49,32,56,12]
y=[22,78,91,45,26]
z=0
try:
  print(x[1])
  x[1]=a
  print(a/z)
  print(y[5])
except ZeroDivisionError:
  print("You can't divide a number with zero")
except IndexError:
  print("Index not available")
else:
  print("Success!!!!")
finally:
  print("Done with Python!!")
# Out:
# 55
# You can't divide a number with zero
# Done with Python!!
